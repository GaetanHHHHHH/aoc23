# %%
# Get input
input_test = ['467..114..',
              '...*......',
              '..35..633.',
              '......#...',
              '617*......',
              '.....+.58.',
              '..592.....',
              '......755.',
              '...$.*....',
              '.664.598..']
inpute = open("./input.txt").read().splitlines()

# %%
# Imports
import re
import copy

# %% [markdown]
# ## Part 1

# %%
# Get list of all special characters
remove = '.0123456789'
symbols = ''

for elem in inpute:
    for char in elem:
        if (char not in remove) and (char not in symbols):
            symbols += char

print(symbols)
# Out:
# +*%#/@$-&=

# %%
# Get index of every digit and every number by row
nb_indexes = []
symb_indexes = []
numbers = []

for i in range(0, len(inpute)):
    numbers.append(re.findall(r'\d+', inpute[i]))
    print(numbers)
    for j in range(0, len(inpute[i])):
        if inpute[i][j].isnumeric():
            nb_indexes.append([i, j])
        if inpute[i][j] in symbols:
            symb_indexes.append([i, j])

#print(nb_indexes)
#print(symb_indexes)
#print(numbers[0])
# Out:
# [['389', '314', '206', '449', '523', '138']]
# [['389', '314', '206', '449', '523', '138'], ['954', '723', '687', '692']]
# [['389', '314', '206', '449', '523', '138'], ['954', '723', '687', '692'], ['121', '992', '585', '814', '936', '102', '353', '140', '434', '301', '315']]
# [['389', '314', '206', '449', '523', '138'], ['954', '723', '687', '692'], ['121', '992', '585', '814', '936', '102', '353', '140', '434', '301', '315'], ['877', '523', '489', '380', '174', '263', '824', '710']]
# [['389', '314', '206', '449', '523', '138'], ['954', '723', '687', '692'], ['121', '992', '585', '814', '936', '102', '353', '140', '434', '301', '315'], ['877', '523', '489', '380', '174', '263', '824', '710'], ['733', '758', '435', '656', '483', '855', '154', '779', '674', '320', '373']]
# ...

# %%
# Get new unique numbers to be able to use them as dict keys
new_numbers = copy.deepcopy(numbers)

for i in range(0, len(new_numbers)):
    for j in range(0, len(new_numbers[i])):
        new_numbers[i][j] = numbers[i][j] + ''.join(random.choice(string.ascii_letters) for x in range(3))

#print(len(new_numbers))
#print(len(numbers))

# %%
# Put numbers as keys and indexes as values
count = 0
dict = {}

for i in range(0, len(new_numbers)):
    for j in range(0, len(new_numbers[i])):
        for x in range(0, len(new_numbers[i][j])-3):
            if new_numbers[i][j] in dict:
                dict[new_numbers[i][j]].append(nb_indexes[count])
            else:
                dict[new_numbers[i][j]] = [nb_indexes[count]]
            count += 1

#print(dict)

# %%
numbers_to_add = []

for key in dict.keys():
    for val in dict[key]:
        under = [val[0] + 1, val[1]]
        over = [val[0] - 1, val[1]]
        right = [val[0], val[1] + 1]
        left = [val[0], val[1] - 1]
        diag_top_left = [val[0] + 1, val[1] - 1]
        diag_top_right = [val[0] + 1, val[1] + 1]
        diag_bottom_left = [val[0] - 1, val[1] - 1]
        diag_bottom_right = [val[0] - 1, val[1] + 1]
        
        if (key not in numbers_to_add) and (
            (under in symb_indexes) or (over in symb_indexes) 
            or (right in symb_indexes) or (left in symb_indexes) 
            or (diag_top_left in symb_indexes) or (diag_top_right in symb_indexes) 
            or (diag_bottom_left in symb_indexes) or (diag_bottom_right in symb_indexes)
        ):
            numbers_to_add.append(key)

#print(numbers_to_add)

# %%
sum = 0

for num in numbers_to_add:
    sum += int(num[:-3])

print(sum)
# Out:
# 530849

# %% [markdown]
# ## Part 2

# %%
# Define gear
gear = '*'

# %%
# Get index of every digit and every number by row
nb_index = []
gears_index = {}
id = 1
numbers = []

for i in range(0, len(inpute)):
    numbers.append(re.findall(r'\d+', inpute[i]))
    for j in range(0, len(inpute[i])):
        if inpute[i][j].isnumeric():
            nb_index.append([i, j])
        if inpute[i][j]==gear:
            gears_index[id] = [i,j]
            id += 1

#print(gears_index)

# %%
# Get new unique numbers to be able to use them as dict keys
new_numbers = copy.deepcopy(numbers)

for i in range(0, len(new_numbers)):
    for j in range(0, len(new_numbers[i])):
        new_numbers[i][j] = numbers[i][j] + ''.join(random.choice(string.ascii_letters) for x in range(3))

# %%
# Put numbers as keys and indexes as values
count = 0
dict = {}

for i in range(0, len(new_numbers)):
    for j in range(0, len(new_numbers[i])):
        for x in range(0, len(new_numbers[i][j])-3):
            if new_numbers[i][j] in dict:
                dict[new_numbers[i][j]].append(nb_index[count])
            else:
                dict[new_numbers[i][j]] = [nb_index[count]]
            count += 1

#print(dict)

# %%
numbers_to_add = []
gears_nb = {}

for key_gear, value_gear in gears_index.items():
    under = [value_gear[0] + 1, value_gear[1]]
    over = [value_gear[0] - 1, value_gear[1]]
    right = [value_gear[0], value_gear[1] + 1]
    left = [value_gear[0], value_gear[1] - 1]
    diag_top_left = [value_gear[0] + 1, value_gear[1] - 1]
    diag_top_right = [value_gear[0] + 1, value_gear[1] + 1]
    diag_bottom_left = [value_gear[0] - 1, value_gear[1] - 1]
    diag_bottom_right = [value_gear[0] - 1, value_gear[1] + 1]

    for key_nb, value_nb in dict.items():
        if ((under in value_nb) or (over in value_nb) 
            or (right in value_nb) or (left in value_nb) 
            or (diag_top_left in value_nb) or (diag_top_right in value_nb) 
            or (diag_bottom_left in value_nb) or (diag_bottom_right in value_nb)
        ):
            if key_gear in gears_nb.keys():
                gears_nb[key_gear].append(key_nb)
            else:
                gears_nb[key_gear] = [key_nb]

#print(gears_nb)

# %%
sum = 0

for key, value in gears_nb.items():
    if len(value) > 1:
        sum += int(value[0][:-3])*int(value[1][:-3])

print(sum)
# Out:
# 84900879
